# %% [markdown]
# ## El Quirófano de Datos

# %%
import pandas as pd
import numpy as np
 
 
# Reemplaza con la URL de tu repositorio
url = "https://raw.githubusercontent.com/mricardo89/data-mining/main/Unit-II/datasets/googleplaystore.csv"
df = pd.read_csv(url)

# %% [markdown]
# Pregunta A: Ejecuten df.isnull().sum(). Identificarán que la columna Rating tiene casi 1,500 valores nulos, mientras que Type y Android Ver tienen solo 1 o 2. ¿Por qué es arquitectónicamente seguro eliminar las filas donde falta Android Ver, pero sería un error fatal eliminar las filas donde falta Rating?
#
# Entre miles de datos no afecta mucho eliminar 3 registros pero eliminar por su totalidd o no tomar en cuenta 1474 registros, se puede dejar de inferir demasiada informacion resultando en un modelo impresisio

# %%
# Pregunta A
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# Pregunta B: Escriban la instrucción exacta usando dropna() pasándole el parámetro subset=['Android Ver', 'Type'] para eliminar únicamente las 3 filas que tienen esos nulos. Verifiquen que el total de registros en el DataFrame apenas disminuyó.
#
# Apenas disminuyo por 4

# %%
# Pregunta B
print(df.shape)
df = df.dropna(subset=['Android Ver', 'Type'])
print(df.shape)
# Out:
# (10841, 13)
# (10837, 13)

# %% [markdown]
# Pregunta C: Rellenar los 1,500 nulos de Rating con el promedio global es un error, ya que las apps de la categoría FAMILY (Familia) no se califican igual que las de DATING (Citas). Utilizando la lógica de la semana pasada, escriban un bloque combinando .groupby('Category') y .transform() para rellenar los NaN de la columna Rating usando la mediana de su propia categoría.
#
# Liston

# %%
# Pregunta C 
print("Hay nulos rating?", df['Rating'].isna().sum())
print('before')
print(df.groupby('Category')['Rating'].count())
df['Rating'] = df['Rating'].fillna(df.groupby('Category')['Rating'].transform('median'))
print('after')
print(df.groupby('Category')['Rating'].count())
print("Hay nulos rating?", df['Rating'].isna().sum())
# Out:
# Hay nulos rating? 1473
# before
# Category
# ART_AND_DESIGN           62
# AUTO_AND_VEHICLES        73
# BEAUTY                   42
# BOOKS_AND_REFERENCE     178
# BUSINESS                303
# COMICS                   58
# COMMUNICATION           328
# DATING                  195
# EDUCATION               155
# ENTERTAINMENT           149
# EVENTS                   45
# FAMILY                 1747
# FINANCE                 323
# FOOD_AND_DRINK          109
# GAME                   1097
# HEALTH_AND_FITNESS      297
# HOUSE_AND_HOME           76
# LIBRARIES_AND_DEMO       65
# LIFESTYLE               314
# MAPS_AND_NAVIGATION     124
# MEDICAL                 350
# NEWS_AND_MAGAZINES      233
# PARENTING                50
# PERSONALIZATION         312
# PHOTOGRAPHY             317
# PRODUCTIVITY            351
# SHOPPING                238
# SOCIAL                  259
# SPORTS                  319
# TOOLS                   734
# TRAVEL_AND_LOCAL        226
# VIDEO_PLAYERS           160
# WEATHER                  75
# Name: Rating, dtype: int64
# after
# Category
# ART_AND_DESIGN           65
# AUTO_AND_VEHICLES        85
# BEAUTY                   53
# BOOKS_AND_REFERENCE     231
# BUSINESS                460
# COMICS                   60
# COMMUNICATION           387
# DATING                  234
# EDUCATION               156
# ENTERTAINMENT           149
# EVENTS                   64
# FAMILY                 1971
# FINANCE                 366
# FOOD_AND_DRINK          127
# GAME                   1144
# HEALTH_AND_FITNESS      341
# HOUSE_AND_HOME           88
# LIBRARIES_AND_DEMO       85
# LIFESTYLE               382
# MAPS_AND_NAVIGATION     137
# MEDICAL                 463
# NEWS_AND_MAGAZINES      283
# PARENTING                60
# PERSONALIZATION         390
# PHOTOGRAPHY             335
# PRODUCTIVITY            424
# SHOPPING                260
# SOCIAL                  295
# SPORTS                  384
# TOOLS                   843
# TRAVEL_AND_LOCAL        258
# VIDEO_PLAYERS           175
# WEATHER                  82
# Name: Rating, dtype: int64
# Hay nulos rating? 0

# %% [markdown]
# Pregunta D: Revisen la columna Size (Tamaño de la app). Notarán que no tiene nulos matemáticos (NaN), pero muchas filas dicen "Varies with device". Para un modelo matemático, ese texto es basura indigerible. Escriban una instrucción usando df['Size'].replace(...) para convertir exactamente esa frase de texto en un nulo matemático real usando np.nan de NumPy. ¿Por qué es mejor convertirlo a NaN en esta etapa en lugar de ponerle un tamaño falso como "0 MB"?
#
# Si le pusieramos 0 MB estariamos creando ruido innecesario totalmente, mejor nomas ponerle null para no tomar en cuenta esas instancias donde varies with device puede significar muchas cosas en un rango muy grande

# %%
# Pregunta D
print("Hay nulos size?", df['Size'].isna().sum())
df['Size'] = df['Size'].replace('Varies with device', np.nan)
print("Hay nulos size?", df['Size'].isna().sum())
# Out:
# Hay nulos size? 0
# Hay nulos size? 1694

# %%
df['Installs'].mean()
df['Price'].max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df['Installs'].mean()
#       2 df['Price'].max()
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/util/_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/series.py:8113, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    8063 @deprecate_nonkeyword_arguments(Pandas4Warning, allowed_args=["self"], name="mean")
#    8064 def mean(
#    8065     self,
#    (...)   8069     **kwargs,
#    8070 ) -> Any:
#    8071     """
#    8072     Return the mean of the values over the requested axis.
#    8073
#    (...)   8111     2.0
#    8112     """
# -> 8113     return NDFrame.mean(
#    8114         self, axis=axis, skipna=skipna, numeric_only=numeric_only, **kwargs
#    8115     )
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/generic.py:11819, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11811 def mean(
#   11812     self,
#   11813     *,
#    (...)  11817     **kwargs,
#   11818 ) -> Series | float:
# > 11819     return self._stat_function(
#   11820         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11821     )
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/generic.py:11773, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11769 nv.validate_func(name, (), kwargs)
#   11771 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11773 return self._reduce(
#   11774     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11775 )
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/series.py:7480, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    7476     self._get_axis_number(axis)
#    7478 if isinstance(delegate, ExtensionArray):
#    7479     # dispatch to ExtensionArray interface
# -> 7480     result = delegate._reduce(name, skipna=skipna, **kwds)
#    7482 else:
#    7483     # dispatch to numpy arrays
#    7484     if numeric_only and self.dtype.kind not in "iufcb":
#    7485         # i.e. not is_numeric_dtype(self.dtype)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/arrays/string_.py:968, in StringArray._reduce(self, name, skipna, keepdims, axis, **kwargs)
#     965         return self._from_sequence([result], dtype=self.dtype)
#     966     return result
# --> 968 raise TypeError(f"Cannot perform reduction '{name}' with string dtype")
#
# TypeError: Cannot perform reduction 'mean' with string dtype
